# %%
# %load_ext autoreload
# %autoreload 2

from amber.store import LocalStore
from amber.adapters.text_snippet_dataset import TextSnippetDataset

from amber.core.language_model import LanguageModel

model = LanguageModel.from_huggingface(
    "sshleifer/tiny-gpt2",
)
dataset = TextSnippetDataset.from_huggingface(
    "roneneldan/TinyStories",
    split="train",
    cache_dir="./cache/tinystories",
    text_field="text",
    limit=100
)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Saving the dataset (1/1 shards): 100%|██████████| 100/100 [00:00<00:00, 58076.77 examples/s]

# %%
model.layers.get_layer_names()
# Out:
# ['gpt2lmheadmodel_transformer',
#  'gpt2lmheadmodel_transformer_wte',
#  'gpt2lmheadmodel_transformer_wpe',
#  'gpt2lmheadmodel_transformer_drop',
#  'gpt2lmheadmodel_transformer_h',
#  'gpt2lmheadmodel_transformer_h_0',
#  'gpt2lmheadmodel_transformer_h_0_ln_1',
#  'gpt2lmheadmodel_transformer_h_0_attn',
#  'gpt2lmheadmodel_transformer_h_0_attn_c_attn',
#  'gpt2lmheadmodel_transformer_h_0_attn_c_proj',
#  'gpt2lmheadmodel_transformer_h_0_attn_attn_dropout',
#  'gpt2lmheadmodel_transformer_h_0_attn_resid_dropout',
#  'gpt2lmheadmodel_transformer_h_0_ln_2',
#  'gpt2lmheadmodel_transformer_h_0_mlp',
#  'gpt2lmheadmodel_transformer_h_0_mlp_c_fc',
#  'gpt2lmheadmodel_transformer_h_0_mlp_c_proj',
#  'gpt2lmheadmodel_transformer_h_0_mlp_act',
#  'gpt2lmheadmodel_transformer_h_0_mlp_dropout',
#  'gpt2lmheadmodel_transformer_h_1',
#  'gpt2lmheadmodel_transformer_h_1_ln_1',
#  'gpt2lmheadmodel_transformer_h_1_attn',
#  'gpt2lmheadmodel_transformer_h_1_attn_c_attn',
#  'gpt2lmheadmodel_transformer_h_1_attn_c_proj',
#  'gpt2lmheadmodel_transformer_h_1_attn_attn_dropout',
#  'gpt2lmheadmodel_transformer_h_1_attn_resid_dropout',
#  'gpt2lmheadmodel_transformer_h_1_ln_2',
#  'gpt2lmheadmodel_transformer_h_1_mlp',
#  'gpt2lmheadmodel_transformer_h_1_mlp_c_fc',
#  'gpt2lmheadmodel_transformer_h_1_mlp_c_proj',
#  'gpt2lmheadmodel_transformer_h_1_mlp_act',
#  'gpt2lmheadmodel_transformer_h_1_mlp_dropout',
#  'gpt2lmheadmodel_transformer_ln_f',
#  'gpt2lmheadmodel_lm_head']

# %%
layer_signature = 'gpt2lmheadmodel_lm_head'

model.activations.infer_and_save(
    dataset,
    layer_signature,
    'test_run',
    batch_size=4,
    verbose=True
)
# Out:
# 2025-09-29 14:34:52,625 [INFO] amber.core.language_model_activations: Starting save_model_activations: run=test_run, layer=gpt2lmheadmodel_lm_head, batch_size=4, device=cpu
# 2025-09-29 14:34:52,626 [INFO] amber.core.language_model_activations: Prepared batch 0: items=4, seq_len=212
# 2025-09-29 14:34:52,675 [INFO] amber.core.language_model_activations: Saved batch 0 for run=test_run with keys=['activations', 'input_ids', 'attention_mask']
# 2025-09-29 14:34:52,677 [INFO] amber.core.language_model_activations: Prepared batch 1: items=4, seq_len=181
# 2025-09-29 14:34:52,715 [INFO] amber.core.language_model_activations: Saved batch 1 for run=test_run with keys=['activations', 'input_ids', 'attention_mask']
# 2025-09-29 14:34:52,716 [INFO] amber.core.language_model_activations: Prepared batch 2: items=4, seq_len=210
# 2025-09-29 14:34:52,762 [INFO] amber.core.language_model_activations: Saved batch 2 for run=test_run with keys=['activations', 'input_ids', 'attention_mask']
# 2025-09-29 14:34:52,764 [INFO] amber.core.language_model_activations: Prepared batch 3: items=4, seq_len=219
# 2025-09-29 14:34:52,813 [INFO] amber.core.language_model_activations: Saved batch 3 for run=test_run with keys=['activations', 'input_ids', 'attention_mask']
# 2025-09-29 14:34:52,814 [INFO] amber.core.language_model_activations: Prepared batch 4: items=4, seq_len=217
# 2025-09-29 14:34:52,862 [INFO] amber.core.language_model_activations: Saved batch 4 for run=test_run with keys=['activations', 'input_ids', 'attention_mask']
# 2025-09-29 14:34:52,864 [INFO] amber.core.language_model_activations: Prepared batch 5: items=4, seq_len=247
# 2025-09-29 14:34:52,914 [INFO] amber.core.language_model_activations: Saved batch 5 for run=test_run with keys=['activations', 'input_ids', 'attention_mask']
# 2025-09-29 14:34:52,915 [INFO] amber.core.language_model_activations: Prepared batch 6: items=4, seq_len=175
# 2025-09-29 14:34:52,956 [INFO] amber.core.language_model_activations: Saved batch 6 for run=test_run with keys=['activations', 'input_ids', 'attention_mask']
# 2025-09-29 14:34:52,957 [INFO] amber.core.language_model_activations: Prepared batch 7: items=4, seq_len=186
# 2025-09-29 14:34:52,997 [INFO] amber.core.language_model_activations: Saved batch 7 for run=test_run with keys=['activations', 'input_ids', 'attention_mask']
# 2025-09-29 14:34:52,998 [INFO] amber.core.language_model_activations: Prepared batch 8: items=4, seq_len=241
# 2025-09-29 14:34:53,047 [INFO] amber.core.language_model_activations: Saved batch 8 for run=test_run with keys=['activations', 'input_ids', 'attention_mask']
# 2025-09-29 14:34:53,048 [INFO] amber.core.language_model_activations: Prepared batch 9: items=4, seq_len=173
# 2025-09-29 14:34:53,087 [INFO] amber.core.language_model_activations: Saved batch 9 for run=test_run with keys=['activations', 'input_ids', 'attention_mask']
# 2025-09-29 14:34:53,089 [INFO] amber.core.language_model_activations: Prepared batch 10: items=4, seq_len=270
# 2025-09-29 14:34:53,145 [INFO] amber.core.language_model_activations: Saved batch 10 for run=test_run with keys=['activations', 'input_ids', 'attention_mask']
# 2025-09-29 14:34:53,146 [INFO] amber.core.language_model_activations: Prepared batch 11: items=4, seq_len=233
# 2025-09-29 14:34:53,195 [INFO] amber.core.language_model_activations: Saved batch 11 for run=test_run with keys=['activations', 'input_ids', 'attention_mask']
# 2025-09-29 14:34:53,196 [INFO] amber.core.language_model_activations: Prepared batch 12: items=4, seq_len=192
# 2025-09-29 14:34:53,237 [INFO] amber.core.language_model_activations: Saved batch 12 for run=test_run with keys=['activations', 'input_ids', 'attention_mask']
# 2025-09-29 14:34:53,239 [INFO] amber.core.language_model_activations: Prepared batch 13: items=4, seq_len=231
# 2025-09-29 14:34:53,285 [INFO] amber.core.language_model_activations: Saved batch 13 for run=test_run with keys=['activations', 'input_ids', 'attention_mask']
# 2025-09-29 14:34:53,287 [INFO] amber.core.language_model_activations: Prepared batch 14: items=4, seq_len=264
# 2025-09-29 14:34:53,341 [INFO] amber.core.language_model_activations: Saved batch 14 for run=test_run with keys=['activations', 'input_ids', 'attention_mask']
# 2025-09-29 14:34:53,342 [INFO] amber.core.language_model_activations: Prepared batch 15: items=4, seq_len=266
# 2025-09-29 14:34:53,398 [INFO] amber.core.language_model_activations: Saved batch 15 for run=test_run with keys=['activations', 'input_ids', 'attention_mask']
# 2025-09-29 14:34:53,399 [INFO] amber.core.language_model_activations: Prepared batch 16: items=4, seq_len=236
# 2025-09-29 14:34:53,448 [INFO] amber.core.language_model_activations: Saved batch 16 for run=test_run with keys=['activations', 'input_ids', 'attention_mask']
# 2025-09-29 14:34:53,449 [INFO] amber.core.language_model_activations: Prepared batch 17: items=4, seq_len=219
# 2025-09-29 14:34:53,502 [INFO] amber.core.language_model_activations: Saved batch 17 for run=test_run with keys=['activations', 'input_ids', 'attention_mask']
# 2025-09-29 14:34:53,504 [INFO] amber.core.language_model_activations: Prepared batch 18: items=4, seq_len=219
# 2025-09-29 14:34:53,555 [INFO] amber.core.language_model_activations: Saved batch 18 for run=test_run with keys=['activations', 'input_ids', 'attention_mask']
# 2025-09-29 14:34:53,557 [INFO] amber.core.language_model_activations: Prepared batch 19: items=4, seq_len=254
# 2025-09-29 14:34:53,606 [INFO] amber.core.language_model_activations: Saved batch 19 for run=test_run with keys=['activations', 'input_ids', 'attention_mask']
# 2025-09-29 14:34:53,608 [INFO] amber.core.language_model_activations: Prepared batch 20: items=4, seq_len=241
# 2025-09-29 14:34:53,656 [INFO] amber.core.language_model_activations: Saved batch 20 for run=test_run with keys=['activations', 'input_ids', 'attention_mask']
# 2025-09-29 14:34:53,657 [INFO] amber.core.language_model_activations: Prepared batch 21: items=4, seq_len=239
# 2025-09-29 14:34:53,704 [INFO] amber.core.language_model_activations: Saved batch 21 for run=test_run with keys=['activations', 'input_ids', 'attention_mask']
# 2025-09-29 14:34:53,705 [INFO] amber.core.language_model_activations: Prepared batch 22: items=4, seq_len=235
# 2025-09-29 14:34:53,752 [INFO] amber.core.language_model_activations: Saved batch 22 for run=test_run with keys=['activations', 'input_ids', 'attention_mask']
# 2025-09-29 14:34:53,753 [INFO] amber.core.language_model_activations: Prepared batch 23: items=4, seq_len=278
# 2025-09-29 14:34:53,811 [INFO] amber.core.language_model_activations: Saved batch 23 for run=test_run with keys=['activations', 'input_ids', 'attention_mask']
# 2025-09-29 14:34:53,812 [INFO] amber.core.language_model_activations: Prepared batch 24: items=4, seq_len=298
# 2025-09-29 14:34:53,871 [INFO] amber.core.language_model_activations: Saved batch 24 for run=test_run with keys=['activations', 'input_ids', 'attention_mask']
# 2025-09-29 14:34:53,871 [INFO] amber.core.language_model_activations: Completed save_model_activations: run=test_run, batches_saved=25
